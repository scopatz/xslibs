# %%
import os
import json

import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use("ggplot")
import numpy as np
from numpy.testing import assert_array_equal, assert_array_almost_equal
import pandas as pd
from pyne import bins
from pyne import origen22

relerror = lambda x, y: abs(x - y) / (abs(x + y)/2)

output_dir = os.path.expanduser("build-lwr1g/brightlite0")
outfile_path = os.path.join(output_dir, "fuel.txt")
klabel = 'Multiplication Factor'
bulabel = 'Burnup [MWd/kg]'
masslabel = 'Mass [g]'
# Out:
# /home/scopatz/miniconda3/lib/python3.4/importlib/_bootstrap.py:321: QAWarning: pyne.bins is not yet QA compliant.
#   return f(*args, **kwds)
# /home/scopatz/miniconda3/lib/python3.4/importlib/_bootstrap.py:321: QAWarning: pyne.data is not yet QA compliant.
#   return f(*args, **kwds)
# /home/scopatz/miniconda3/lib/python3.4/importlib/_bootstrap.py:321: QAWarning: pyne.xs.models is not yet QA compliant.
#   return f(*args, **kwds)
# /home/scopatz/.local/lib/python3.4/site-packages/pyne-0.5.0rc1-py3.4.egg/pyne/openmc.py:18: QAWarning: pyne.openmc is not yet QA compliant.
#   warn(__name__ + " is not yet QA compliant.", QAWarning)
# /home/scopatz/miniconda3/lib/python3.4/importlib/_bootstrap.py:321: QAWarning: pyne.rxname is not yet QA compliant.
#   return f(*args, **kwds)
# /home/scopatz/.local/lib/python3.4/site-packages/pyne-0.5.0rc1-py3.4.egg/pyne/rxdata.py:5: QAWarning: pyne.rxdata is not yet QA compliant.
#   warn(__name__ + " is not yet QA compliant.", QAWarning)
# /home/scopatz/miniconda3/lib/python3.4/importlib/_bootstrap.py:321: QAWarning: pyne.endf is not yet QA compliant.
#   return f(*args, **kwds)
# /home/scopatz/miniconda3/lib/python3.4/importlib/_bootstrap.py:321: QAWarning: pyne.ace is not yet QA compliant.
#   return f(*args, **kwds)
# /home/scopatz/.local/lib/python3.4/site-packages/pyne-0.5.0rc1-py3.4.egg/pyne/xs/data_source.py:29: QAWarning: pyne.xs.data_source is not yet QA compliant.
#   warn(__name__ + " is not yet QA compliant.", QAWarning)
# /home/scopatz/.local/lib/python3.4/site-packages/pyne-0.5.0rc1-py3.4.egg/pyne/xs/cache.py:19: QAWarning: pyne.xs.cache is not yet QA compliant.
#   warn(__name__ + " is not yet QA compliant.", QAWarning)
# /home/scopatz/miniconda3/lib/python3.4/importlib/_bootstrap.py:321: QAWarning: pyne.material is not yet QA compliant.
#   return f(*args, **kwds)
# /home/scopatz/.local/lib/python3.4/site-packages/pyne-0.5.0rc1-py3.4.egg/pyne/origen22.py:28: QAWarning: pyne.origen22 is not yet QA compliant.
#   warn(__name__ + " is not yet QA compliant.", QAWarning)

# %% [markdown]
# ## Xsgen Data

# %%
#xdata = pd.read_csv(outfile_path, delim_whitespace=True, index_col=0).transpose()
xU235 = pd.read_csv(os.path.join(output_dir, '922350.txt'), delim_whitespace=True, index_col=0).transpose()
xU238 = pd.read_csv(os.path.join(output_dir, '922380.txt'), delim_whitespace=True, index_col=0).transpose()
xdata = xU235*0.05 + xU238*0.95
xdata.index = xdata.index.astype('f8')
plt.figure()
xdata.U235.plot(logy=True, figsize=(18, 9))
xdata.U238.plot(logy=True, figsize=(18, 9))
xdata.Pu239.plot(logy=True, figsize=(18, 9))
plt.legend(loc=1)

# %%
plt.figure()
k = (xdata.NEUT_PROD / xdata.NEUT_DEST)
k.name = 'k'
k.plot(figsize=(18, 9))
plt.legend(loc=2)
BUd = xdata.BUd.cumsum()
BUd.name = 'BUd'
ax = BUd.plot(secondary_y=True)
ax.legend(loc=1)

# %% [markdown]
# ## Bright-lite Comparison

# %%
#xU235 = pd.read_csv(os.path.join(output_dir, '922350.txt'), delim_whitespace=True, index_col=0).transpose()
bU235 = pd.read_csv('/home/scopatz/.local/share/brightlite/extLWR/922350.txt', delim_whitespace=True, index_col=0).transpose()
bU238 = pd.read_csv('/home/scopatz/.local/share/brightlite/extLWR/922380.txt', delim_whitespace=True, index_col=0).transpose()
bdata = bU235*0.05 + bU238*0.95
bdata.U235 = bU235.U235*0.05
bdata.index = bdata.index.astype('f8')

# %%
plt.figure()
xdata.U235.plot(logy=True, style='r-', figsize=(18, 9), label='U-235 (xsgen)')
xdata.U238.plot(logy=True, style='b-', figsize=(18, 9), label='U-238 (xsgen)')
xdata.Pu239.plot(logy=True, style='m-', figsize=(18, 9), label='Pu-239 (xsgen)')
bdata.U235.plot(logy=True, style='r--', figsize=(18, 9), label='U-235 (Bright-lite)')
bdata.U238.plot(logy=True, style='b--', figsize=(18, 9), label='U-238 (Bright-lite)')
bdata.PU239.plot(logy=True, style='m--', figsize=(18, 9), label='Pu-239 (Bright-lite)')
plt.legend(loc=0)

# %%
plt.figure()
xk = (xdata.NEUT_PROD / xdata.NEUT_DEST)
xk.name = 'k'
xk.plot(style='b-', label='k (xsgen)', figsize=(18, 9))
bk = (bdata.NEUT_PROD / bdata.NEUT_DEST)
bk.name = 'k'
bk.plot(style='b--', label='k (Bright-lite)', figsize=(18, 9))
plt.legend(loc=2)
xBUd = xdata.BUd.cumsum()
xBUd.name = 'BUd'
ax = xBUd.plot(style='r-', label='BUd (xsgen)', secondary_y=True)
bBUd = bdata.BUd.cumsum()
bBUd.name = 'BUd'
ax = bBUd.plot(style='r--', label='BUd (Bright-lite)', secondary_y=True)
ax.legend(loc=1)

# %%
plt.figure()
xk.index = xBUd.values
xk.plot(style='r-', label='xsgen', figsize=(18, 9))
bk.index = bBUd.values
bk.plot(style='b--', label='Bright-lite', figsize=(18, 9))
plt.xlabel(bulabel)
plt.ylabel(klabel)
plt.legend(loc=0)

# %%
relerror(xdata.U238, bdata.U238)
# Out:
# 0       0.000000
# 3       0.000400
# 100     0.008645
# 200     0.024025
# 300     0.050796
# 400     0.062953
# 500     0.076086
# 600     0.081983
# 700     0.086500
# 800     0.099207
# 900     0.111668
# 1000    0.124114
# 1100    0.156542
# 1200    0.160562
# 1300    0.189833
# ...
# 5600    0.545672
# 5700    0.549876
# 5800    0.553173
# 5900    0.560013
# 6000    0.563378
# 6100    0.566877
# 6200    0.574263
# 6300    0.577534
# 6400    0.589753
# 6500    0.593425
# 6600    0.599713
# 6700    0.610080
# 6800    0.615509
# 6900    0.634916
# 7000    0.641786
# Name: U238, Length: 72, dtype: float64

# %%
bt9 = origen22.parse_tape9('/home/scopatz/.local/share/brightlite/extLWR/TAPE9.INP')

# %%
bt9[220]['sigma_gamma'][922350]
# Out:
# 7.9020000000000001

# %%
xt9 = origen22.parse_tape9(os.path.join(output_dir, 'TAPE9.INP'))

# %%
xt9[220]['sigma_gamma'][922350]
# Out:
# 76.689999999999998

# %%
with open(os.path.join(output_dir, 'xs.json'), 'r') as f:
    xsdata = json.load(f)
    
def filter_nuc_rx(nuc, rx):
    dat = []
    for t in xsdata:
        for row in t:
            if row[0] == nuc and row[1] == rx:
                dat.append(row[2])
    return dat

# %%
xsU235 = filter_nuc_rx('U235', 'fission')
xsU235
# Out:
# [676.8011744596186,
#  524.9640494312029,
#  1212.9214429222736,
#  2314.55115431883,
#  928.3945211197055,
#  1032.5957672243317,
#  327.00535058895287,
#  162.10009484643282,
#  991.8076568034138,
#  973.962480992966,
#  935.8886832898374,
#  2881.0950998802255,
#  133.22311145410427,
#  2534.212098620408,
#  353.1203302119735,
#  275.170418673707,
#  84.39687695330207,
#  246.7138198405695,
#  154.53876259691813,
#  246.23113092805102,
#  192.737782908806,
#  972.8670129012197,
#  1356.6533810740102,
#  493.2314009465041,
#  455.5308764065468,
#  529.2304299553952,
#  392.90429615843044,
#  284.9009672299435,
#  748.8377126970013,
#  1339.8030793336745,
#  387.0898769392235,
#  938.3473092897336,
#  211.71619488884443,
#  550.7287920227499,
#  1583.914072776822,
#  106.5157840939136,
#  1867.4634537889472,
#  411.5701430168058,
#  1070.3039890972864,
#  308.05486221497614,
#  409.7862772462495,
#  1107.680348308405,
#  643.5824918747164,
#  129.8573050069001,
#  36.55941288863289,
#  503.3958155718515,
#  36.056905465680785,
#  218.02359082667635,
#  285.10572497604926,
#  35.40606220872974,
#  219.73981745532956,
#  877.1799724307441,
#  222.07038736144003,
#  1390.9270990314722,
#  870.8276787127701,
#  314.8432803641248,
#  460.04568802117063,
#  122.70021013829017,
#  37.45411336558144,
#  412.171871387837,
#  36.99806744578393,
#  37.07437700126824,
#  461.73198365272265,
#  36.961603246700726,
#  982.5451086975027,
#  38.782711273097256,
#  363.6762305534551,
#  795.1451369927823,
#  237.766710185762,
#  1725.0033603675158,
#  395.7674784683993]

# %%
filter_nuc_rx('U238', 'total')
# Out:
# [17.55760091680987,
#  17.055934023933748,
#  20.389974158375708,
#  26.039221583061327,
#  19.09561238252928,
#  19.54962109766221,
#  15.928343002378602,
#  15.022687211458212,
#  19.425035548745534,
#  19.2305093124509,
#  19.176241741254824,
#  29.085655479712607,
#  15.163126890200349,
#  27.16902312902963,
#  16.250472869502836,
#  15.792410168954467,
#  14.731732214744746,
#  15.591908537730871,
#  15.195254079637913,
#  15.732271655034776,
#  15.42056204706359,
#  19.380256047053848,
#  21.292868394097408,
#  17.018074386759423,
#  16.59787034940633,
#  17.04033830549866,
#  16.305800958220953,
#  15.905000399951028,
#  18.20530991817927,
#  21.27412978009012,
#  16.47857542823185,
#  19.33532072135558,
#  15.377616101874839,
#  17.365891090481107,
#  22.565030695811572,
#  14.924933805834636,
#  23.97197771715882,
#  16.547084427952345,
#  19.885539233697852,
#  15.955645180270123,
#  16.393340703414076,
#  20.094119639153107,
#  17.734597624801676,
#  15.163685221959533,
#  14.613574160637384,
#  17.179517533573986,
#  14.834449369819385,
#  15.565785554840694,
#  16.027747522771726,
#  14.604249941754144,
#  15.777487182022439,
#  19.088940755398905,
#  15.853384334461529,
#  21.617182304819607,
#  18.96307633366392,
#  16.221421731616203,
#  16.890023645287698,
#  15.203748778994758,
#  14.781350464619674,
#  16.77853730827964,
#  14.724845731899098,
#  14.844550840642807,
#  17.074008357058723,
#  14.840114999679988,
#  19.727537001202748,
#  14.938420474862907,
#  16.46290847263896,
#  18.670065671450057,
#  15.917996677867526,
#  23.45478667472553,
#  16.856946818554064]

# %%
with open(os.path.join(output_dir, 'phi_g.json'), 'r') as f:
    phi_g = json.load(f)

# %%
fig = plt.figure(figsize=(18, 9))
plt.loglog(*bins.stair_step(phi_g['E_g']['OpenMC'], phi_g['phi_g'][0]['OpenMC']), label='0 days', figure=fig)
plt.loglog(*bins.stair_step(phi_g['E_g']['OpenMC'], phi_g['phi_g'][-1]['OpenMC']), label='7000 days',figure=fig)
plt.xlabel('Neutron Energy [MeV]')
plt.ylabel('Normalized Group Fluxes, $\phi_g$ [n/s/cm$^2$]')
plt.legend(loc=0)

# %%
#assert_array_equal(phi_g['phi_g'][0]['OpenMC'], phi_g['phi_g'][-1]['OpenMC'])

# %%
all([((np.array(phi_g['phi_g'][i]['OpenMC']) - np.array(phi_g['phi_g'][0]['OpenMC'])) == 0.0).all() 
    for i in range(1, len(phi_g['phi_g']))])
# Out:
# False
